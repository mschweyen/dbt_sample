# %%
# info vbu reference:
# https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.close("all")
np.random.seed(123456)
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
# df = pd.DataFrame({"lab": ["A", "B", "C"], "val": [10, 30, 20]})
# ax = df.plot.bar(x="lab", y="val", rot=0)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
display(df)
df = df.cumsum()
plt.figure();
df.plot();
# Out:
#                    A         B         C         D
# 2000-01-01 -2.206289 -0.363620 -0.041300 -0.666240
# 2000-01-02 -1.143515 -2.012496 -0.889522  0.207212
# 2000-01-03 -0.675828  0.508942 -0.316892  0.120754
# 2000-01-04  0.220305 -0.708391 -0.928372  2.405687
# 2000-01-05 -0.101516  0.026741 -0.025954 -1.085096
# ...              ...       ...       ...       ...
# 2002-09-22  1.618205 -0.322357 -0.464255 -0.893179
# 2002-09-23  1.685531 -0.534832 -0.638054 -2.511200
# 2002-09-24  1.422141  0.448022 -0.332452 -0.104184
# 2002-09-25 -0.032757 -0.107680  0.233257 -0.607882
# 2002-09-26  0.678259 -1.162712  0.044858 -1.904310
#
# [1000 rows x 4 columns]

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3["A"] = pd.Series(list(range(len(df))))
df3.plot(x="A", y="B");

# %%
plt.figure();
df.iloc[5].plot(kind="bar");

# %%
df = pd.DataFrame()

# %%
df.plot.    # noqa: E225, E999
# Out:
#   Cell In[11], line 1
#     df.plot.    # noqa: E225, E999
#                 ^
# SyntaxError: invalid syntax

# %%
plt.figure();
df.iloc[5].plot.bar();
plt.axhline(0, color="k");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 plt.figure();
# ----> 2 df.iloc[5].plot.bar();
#       3 plt.axhline(0, color="k");
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\core\indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\core\indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
#    1704 len_axis = len(self.obj._get_axis(axis))
#    1705 if key >= len_axis or key < -len_axis:
# -> 1706     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)


plt.figure();

df4.plot.hist(alpha=0.5);

# %%
plt.figure();
df4.plot.hist(stacked=True, bins=20);

# %%
plt.figure();
df4["a"].plot.hist(orientation="horizontal", cumulative=True);

# %%
plt.figure();
df["A"].diff().hist();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 plt.figure();
# ----> 2 df["A"].diff().hist();
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'A'

# %%
plt.figure();
df.diff().hist(color="k", alpha=0.5, bins=50);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 plt.figure();
# ----> 2 df.diff().hist(color="k", alpha=0.5, bins=50);
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\plotting\_core.py:258, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     168 """
#     169 Make a histogram of the DataFrame's columns.
#     170
#    (...)    255     >>> hist = df.hist(bins=3)
#     256 """
#     257 plot_backend = _get_plot_backend(backend)
# --> 258 return plot_backend.hist_frame(
#     259     data,
#     260     column=column,
#     261     by=by,
#     262     grid=grid,
#     263     xlabelsize=xlabelsize,
#     264     xrot=xrot,
#     265     ylabelsize=ylabelsize,
#     266     yrot=yrot,
#     267     ax=ax,
#     268     sharex=sharex,
#     269     sharey=sharey,
#     270     figsize=figsize,
#     271     layout=layout,
#     272     legend=legend,
#     273     bins=bins,
#     274     **kwargs,
#     275 )
#
# File ~\PycharmProjects\dbt_sample_dz\.venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:545, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     542 naxes = len(data.columns)
#     544 if naxes == 0:
# --> 545     raise ValueError(
#     546         "hist method requires numerical or datetime columns, nothing to plot."
#     547     )
#     549 fig, axes = create_subplots(
#     550     naxes=naxes,
#     551     ax=ax,
#    (...)    556     layout=layout,
#     557 )
#     558 can_set_label = "label" not in kwds
#
# ValueError: hist method requires numerical or datetime columns, nothing to plot.

# %%
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
data = pd.DataFrame(
    {
        "a": np.random.choice(["x", "y", "z"], 1000),
        "b": np.random.choice(["e", "f", "g"], 1000),
        "c": np.random.randn(1000),
        "d": np.random.randn(1000) - 1,
    },
)


data.plot.hist(by=["a", "b"], figsize=(10, 5));
